# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, MaxPooling2D, Conv2D, Dropout, Input
import numpy as np
import matplotlib.pyplot as plt

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1), (10000, 32, 32, 3), (10000, 1))

# %%
X_train, X_test = X_train / 255.0, X_test / 255.0

# %%
model = Sequential([
	Input(shape=(32, 32 ,3)),
	Conv2D(32, kernel_size=(3, 3), activation='relu'),
	MaxPooling2D(),
	Conv2D(64, kernel_size=(3, 3), activation='relu'),
	MaxPooling2D(),
	Conv2D(128, kernel_size=(3, 3), activation='relu'),
	MaxPooling2D(),
	Flatten(),
	Dense(64, activation='relu'),
	Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs=5, validation_data=(X_test, y_test))
# Out:
# Epoch 1/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.3491 - loss: 1.7494 - val_accuracy: 0.5415 - val_loss: 1.2806
# Epoch 2/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.5763 - loss: 1.1963 - val_accuracy: 0.6030 - val_loss: 1.1204
# Epoch 3/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.6415 - loss: 1.0254 - val_accuracy: 0.6467 - val_loss: 1.0112
# Epoch 4/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6858 - loss: 0.9052 - val_accuracy: 0.6683 - val_loss: 0.9615
# Epoch 5/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7173 - loss: 0.8182 - val_accuracy: 0.6855 - val_loss: 0.9113

# %%
loss, accuracy = model.evaluate(X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6871 - loss: 0.9051

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
